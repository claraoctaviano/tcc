# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Created a list to append all tweet attributes(data)
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:fatooufake').get_items()):
    if i>100:
        break
    attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe from the tweets list above 
tweets_df = pd.DataFrame(attributes_container, columns=["Date Created", "Number of Likes", "Source of Tweet", "Tweets"])
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_27012\1542078816.py:11: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])

# %%
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:fatooufake').get_items()):
    if i>100:
        break
    attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
    
  
# Creating a dataframe from the tweets list above 
tweets_df = pd.DataFrame(attributes_container, columns=["Date Created", "Number of Likes", "Source of Tweet", "Tweets"])
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_27012\4240363845.py:4: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])

# %%
tweets_df.head(50)

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
attributes_container = []
users_name = ['fatooufake', 'uolconfere', 'estadaoverifica', 'agencialupa']

# Using TwitterSearchScraper to scrape data and append tweets to list
for n, k in enumerate(users_name):
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('since:2020-05-01 until:2022-08-01').get_items()):
        if i>100000: #delimita o número de tweets no df final
            break
        attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Number of Quotes", "Number of Replies", "Source of Tweet", "Tweet"])

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('fatooufake since:2020-05-01 until:2022-09-01').get_items()):
    if i>50000: #delimita o número de tweets no df final
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Number of Quotes", "Number of Replies", "Source of Tweet", "Tweet"])
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_40272\2300866678.py:11: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])

# %%
username_fatooufake = tweets_df[tweets_df['User'] == 'fatooufake']

# %%
username_fatooufake
# Out:
#              User              Date Created  Number of Likes  \
# 2      fatooufake 2022-08-31 21:39:32+00:00                4
# 7      fatooufake 2022-08-31 18:10:35+00:00                7
# 21     fatooufake 2022-08-30 23:01:07+00:00                7
# 24     fatooufake 2022-08-30 20:25:00+00:00                7
# 25     fatooufake 2022-08-30 20:05:00+00:00                6
# ...           ...                       ...              ...
# 15545  fatooufake 2020-05-01 02:20:00+00:00               39
# 15550  fatooufake 2020-05-01 01:50:00+00:00              314
# 15554  fatooufake 2020-05-01 01:20:00+00:00               40
# 15558  fatooufake 2020-05-01 00:50:00+00:00               63
# 15560  fatooufake 2020-05-01 00:21:39+00:00               42
#
#        Number of Retweets  Number of Quotes  Number of Replies  \
# 2                       0                 0                  2
# 7                       0                 0                  1
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('agencialupa since:2020-05-01 until:2022-09-01').get_items()):
    if i>50000: #delimita o número de tweets no df final
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Number of Quotes", "Number of Replies", "Source of Tweet", "Tweet"])
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_40272\3718816367.py:11: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])

# %%
username_lupa = tweets_df[tweets_df['User'] == 'agencialupa']

# %%
username_lupa
# Out:
#               User              Date Created  Number of Likes  \
# 9      agencialupa 2022-08-31 23:00:00+00:00               37
# 50     agencialupa 2022-08-31 19:00:06+00:00               47
# 151    agencialupa 2022-08-31 11:00:00+00:00               71
# 231    agencialupa 2022-08-30 23:02:34+00:00              508
# 243    agencialupa 2022-08-30 22:10:23+00:00               22
# ...            ...                       ...              ...
# 49993  agencialupa 2021-07-12 23:01:07+00:00               17
# 49994  agencialupa 2021-07-12 23:01:07+00:00                3
# 49995  agencialupa 2021-07-12 23:01:06+00:00                3
# 49996  agencialupa 2021-07-12 23:01:06+00:00                5
# 49997  agencialupa 2021-07-12 23:01:05+00:00               78
#
#        Number of Retweets  Number of Quotes  Number of Replies  \
# 9                      13                 0                  8
# 50                     12                 0                  3
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('uolconfere since:2020-05-01 until:2022-09-01').get_items()):
    if i>50000: #delimita o número de tweets no df final
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Number of Quotes", "Number of Replies", "Source of Tweet", "Tweet"])
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_40272\1591409031.py:11: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])

# %%
username_uolconfere = tweets_df[tweets_df['User'] == 'uolconfere']

# %%
username_uolconfere
# Out:
#              User              Date Created  Number of Likes  \
# 0      uolconfere 2022-08-31 20:15:39+00:00                2
# 3      uolconfere 2022-08-31 19:39:34+00:00               14
# 4      uolconfere 2022-08-31 18:59:58+00:00                3
# 6      uolconfere 2022-08-31 18:25:46+00:00                8
# 7      uolconfere 2022-08-31 18:16:32+00:00                5
# ...           ...                       ...              ...
# 28559  uolconfere 2020-05-06 17:52:13+00:00                2
# 28560  uolconfere 2020-05-05 19:22:34+00:00                0
# 28561  uolconfere 2020-05-04 18:13:30+00:00                0
# 28562  uolconfere 2020-05-04 17:13:51+00:00                0
# 28563  uolconfere 2020-05-02 18:07:55+00:00                1
#
#        Number of Retweets  Number of Quotes  Number of Replies  \
# 0                       1                 0                  1
# 3                       3                 1                  1
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('estadaoverifica since:2020-05-01 until:2022-09-01').get_items()):
    if i>50000: #delimita o número de tweets no df final
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Number of Quotes", "Number of Replies", "Source of Tweet", "Tweet"])
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_40272\4245076934.py:11: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount, tweet.sourceLabel, tweet.content])

# %%
username_estadao = tweets_df[tweets_df['User'] == 'estadaoverifica']

# %%
username_estadao
# Out:
#                   User              Date Created  Number of Likes  \
# 19     estadaoverifica 2022-08-31 21:54:08+00:00               20
# 24     estadaoverifica 2022-08-31 21:28:09+00:00                4
# 34     estadaoverifica 2022-08-31 20:00:52+00:00               25
# 124    estadaoverifica 2022-08-31 15:35:46+00:00                1
# 173    estadaoverifica 2022-08-31 11:00:21+00:00               10
# ...                ...                       ...              ...
# 49626  estadaoverifica 2021-05-07 13:00:02+00:00                0
# 49734  estadaoverifica 2021-05-06 22:30:00+00:00               65
# 49746  estadaoverifica 2021-05-06 21:10:26+00:00               13
# 49843  estadaoverifica 2021-05-04 21:33:45+00:00                5
# 49852  estadaoverifica 2021-05-04 15:47:53+00:00                3
#
#        Number of Retweets  Number of Quotes  Number of Replies  \
# 19                      7                 0                  0
# ...

# %%
df_full = pd.concat([username_fatooufake, username_estadao, username_lupa, username_uolconfere])

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7141 entries, 2 to 28563
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   User                7141 non-null   object
#  1   Date Created        7141 non-null   datetime64[ns, UTC]
#  2   Number of Likes     7141 non-null   int64
#  3   Number of Retweets  7141 non-null   int64
#  4   Number of Quotes    7141 non-null   int64
#  5   Number of Replies   7141 non-null   int64
#  6   Source of Tweet     7141 non-null   object
#  7   Tweet               7141 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(4), object(3)
# memory usage: 502.1+ KB

# %%
df_full['Date Created'] = df_full['Date Created'].dt.strftime("%Y%m")

# %%
df_full.to_csv("df_tweets_engajamento.csv")
